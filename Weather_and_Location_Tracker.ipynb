# %%
import requests 

res = requests.get('https://ipinfo.io/103.167.115.119/json?token=f72f442c5618ab')
data = res.json()  

citydata = data['city']
print("Current Location:", citydata)

url = 'https://wttr.in/Bhiwani'.format(citydata)
res = requests.get(url)

print(res.text)
# Out:
# Current Location: Bhiwāni
# Weather report: Bhiwani
#
#       \   /     Sunny
#        .-.      +22(23) °C
#     ― (   ) ―   ↘ 19 km/h
#        `-’      10 km
#       /   \     0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 07 Jan ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │     \   /     Sunny          │     \   /     Clear          │     \   /     Clear          │
# │      .-.      15 °C          │      .-.      21 °C          │      .-.      16 °C          │      .-.      +14(13) °C     │
# ...
